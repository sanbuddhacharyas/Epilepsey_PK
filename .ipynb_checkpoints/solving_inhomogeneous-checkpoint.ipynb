# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.integrate import odeint

# %%
# from paper

x_l = 1.5          # meter (length of large intestine is 1.5 meter)
x_s = 3.5          # meter  (5 - 1.5 = 3.5 length of small intestine)
r_s = 1.25         # centimeter
r_l = 2.5          # centimeter
a_s = 0.65         # constant
a_l = 1.0          # constant
Q_s = 3            # mL/min
Q_l = 5            # mL/min
m   = 100          # milligram (dose)

# patient weight
w  = 70            # Kg
Vd = 1    # ranges (0.8–1.2)  # L / kg

# find flow velocity
v_s = Q_s / (np.pi * r_s**2)  # 
v_l = Q_l / (np.pi * r_l**2)  # 

# define carbamazepine drug spread out time scale tou
max_con = 0.5          #
tou     = 20           # hrs

# value to ka and ke which depends upon patients
ka = 0.5               # constant
ke = 0.5               # constant

# %%
# Define saw tooth funnction
def drug_spread_out(t, x):
    t = t - x

    if (t >= 0) and (t < tou /2):
        return (2 / tou**2)*t
    
    elif ((tou/2) < t) and (t < tou):
        return (2 / tou**2)*(tou - t)
    
    else:
        return 0
    
# solving equation for small_intestine
def small_intestine(t, ka):
    x = (x_s * np.pi**2 * r_s**2) / Q_s
    J = m*drug_spread_out(t, x)
    
    return ka*(J*x_s*np.exp(-x_s*a_s/v_s*ka))

# solving equation for large intestine
def large_intestine(t, ka):
    x = ((x_l - x_s) * np.pi**2 * r_l**2) / Q_l
    J = m*drug_spread_out(t, x)
    
    return ka*(J*(x_l - x_s)*np.exp(-(x_l - x_s)*a_l/v_l*ka))

# define ordinary differential equation
def model(b, t):
    A_t  =  small_intestine(t, ka) + large_intestine(t, ka)
    dbdt = 1 / (w * Vd) * (A_t) - ke*b
    
    return dbdt

# %%
b = 0
t = np.linspace(20, 200, 500)
a
# solve the ODE equation
sol = odeint(model, b, t)

# plot results
plt.plot(t, sol)
plt.xlabel('time(hr)')
plt.ylabel('$b(\dfrac{kg}{m^{3}})$')
plt.show()

# %% [markdown]
# Working on Sawtooth wave which repeats after 24 hrs

# %%
#perioid after 24 hrs
pd_time = 24
def find_sawtooth_wave(x, t):
#     J = 0
    pd_ind = t // pd_time
    t      = t - pd_ind * 24 
    J      = m*drug_spread_out(t, x)
    return J

# %%
doeses  = [100, 100]
pd_time = 24

# solving equation for small_intestine
def small_intestine(t, ka):
    x = (x_s * np.pi**2 * r_s**2) / Q_s
    J = find_sawtooth_wave(x, t)
    
    return ka*(J*x_s*np.exp(-x_s*a_s/v_s*ka))

# solving equation for large intestine
def large_intestine(t, ka):
    x = ((x_l - x_s) * np.pi**2 * r_l**2) / Q_l
    J = find_sawtooth_wave(x, t)
    
    return ka*(J*(x_l - x_s)*np.exp(-(x_l - x_s)*a_l/v_l*ka))

# define ordinary differential equation
def model(b, t):
    A_t  =  small_intestine(t, ka) + large_intestine(t, ka)
    dbdt = 1 / (w * Vd) * (A_t) - ke*b
    
    return dbdt

# %%
b = 0
t = np.linspace(20, 50, 100)

# solve the ODE equation
sol = odeint(model, b, t)

# plot results
plt.plot(t, sol)
plt.xlabel('time(hr)')
plt.ylabel('$b(\dfrac{kg}{m^{3}})$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       2 t = np.linspace(20, 50, 100)
#       4 # solve the ODE equation
# ----> 5 sol = odeint(model, b, t)
#       7 # plot results
#       8 plt.plot(t, sol)
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# Cell In[32], line 20, in model(b, t)
#      19 def model(b, t):
# ---> 20     A_t  =  small_intestine(t, ka) + large_intestine(t, ka)
#      21     dbdt = 1 / (w * Vd) * (A_t) - ke*b
#      23     return dbdt
#
# Cell In[32], line 7, in small_intestine(t, ka)
#       5 def small_intestine(t, ka):
#       6     x = (x_s * np.pi**2 * r_s**2) / Q_s
# ----> 7     J = find_sawtooth_wave(x, t)
#       9     return ka*(J*x_s*np.exp(-x_s*a_s/v_s*ka))
#
# Cell In[31], line 6, in find_sawtooth_wave(x, t)
#       3 def find_sawtooth_wave(x, t):
#       4 #     J = 0
# ----> 6     t = t - pd * pd_time
#       7     J = m*drug_spread_out(t, x)
#       8     return J
#
# NameError: name 'pd' is not defined

# %%
#perioid after 24 hrs

def find_sawtooth_wave(x, t):
    J = 0
    for pd, m in enumerate(doeses):
        t = t - pd * pd_time
        print('t', t)
        J += m*drug_spread_out(t, x)
    return J

t = np.linspace(20, 50, 100)
x = 10

sol = [find_sawtooth_wave(x, i) for i in t]

# plot results
plt.plot(t, sol)
plt.xlabel('time(hr)')
plt.ylabel('$b(\dfrac{kg}{m^{3}})$')
plt.show()
# Out:
# t 20.0
# t -4.0
# t 20.303030303030305
# t -3.6969696969696955
# t 20.606060606060606
# t -3.3939393939393945
# t 20.90909090909091
# t -3.09090909090909
# t 21.21212121212121
# t -2.787878787878789
# t 21.515151515151516
# t -2.4848484848484844
# t 21.81818181818182
# t -2.18181818181818
# t 22.12121212121212
# t -1.878787878787879
# t 22.424242424242426
# t -1.5757575757575744
# t 22.727272727272727
# t -1.2727272727272734
# t 23.03030303030303
# t -0.9696969696969688
# t 23.333333333333332
# t -0.6666666666666679
# t 23.636363636363637
# t -0.3636363636363633
# t 23.939393939393938
# t -0.06060606060606233
# t 24.242424242424242
# t 0.2424242424242422
# t 24.545454545454547
# t 0.5454545454545467
# t 24.848484848484848
# t 0.8484848484848477
# t 25.151515151515152
# t 1.1515151515151523
# t 25.454545454545453
# t 1.4545454545454533
# t 25.757575757575758
# t 1.7575757575757578
# t 26.060606060606062
# t 2.0606060606060623
# t 26.363636363636363
# t 2.3636363636363633
# t 26.666666666666668
# t 2.666666666666668
# t 26.96969696969697
# t 2.969696969696969
# t 27.272727272727273
# t 3.2727272727272734
# t 27.575757575757578
# t 3.575757575757578
# t 27.87878787878788
# t 3.878787878787879
# t 28.18181818181818
# t 4.18181818181818
# t 28.484848484848484
# t 4.484848484848484
# t 28.78787878787879
# t 4.787878787878789
# t 29.090909090909093
# t 5.0909090909090935
# t 29.393939393939394
# t 5.3939393939393945
# t 29.696969696969695
# t 5.6969696969696955
# t 30.0
# t 6.0
# t 30.303030303030305
# t 6.3030303030303045
# t 30.606060606060606
# t 6.6060606060606055
# t 30.90909090909091
# t 6.90909090909091
# t 31.21212121212121
# t 7.212121212121211
# t 31.515151515151516
# t 7.515151515151516
# t 31.81818181818182
# t 7.81818181818182
# t 32.121212121212125
# t 8.121212121212125
# t 32.42424242424242
# t 8.424242424242422
# t 32.72727272727273
# t 8.727272727272727
# t 33.03030303030303
# t 9.030303030303031
# t 33.333333333333336
# t 9.333333333333336
# t 33.63636363636364
# t 9.63636363636364
# t 33.93939393939394
# t 9.939393939393938
# t 34.24242424242424
# t 10.242424242424242
# t 34.54545454545455
# t 10.545454545454547
# t 34.84848484848485
# t 10.848484848484851
# t 35.151515151515156
# t 11.151515151515156
# t 35.45454545454545
# t 11.454545454545453
# t 35.75757575757576
# t 11.757575757575758
# t 36.06060606060606
# t 12.060606060606062
# t 36.36363636363636
# t 12.36363636363636
# t 36.66666666666667
# t 12.666666666666671
# t 36.96969696969697
# t 12.969696969696969
# t 37.27272727272727
# t 13.272727272727273
# t 37.57575757575758
# t 13.575757575757578
# t 37.878787878787875
# t 13.878787878787875
# t 38.18181818181819
# t 14.181818181818187
# t 38.484848484848484
# t 14.484848484848484
# t 38.78787878787879
# t 14.787878787878789
# t 39.09090909090909
# t 15.090909090909093
# t 39.39393939393939
# t 15.393939393939391
# t 39.6969696969697
# t 15.696969696969703
# t 40.0
# t 16.0
# t 40.303030303030305
# t 16.303030303030305
# t 40.60606060606061
# t 16.60606060606061
# t 40.90909090909091
# t 16.909090909090907
# t 41.21212121212121
# t 17.21212121212121
# t 41.515151515151516
# t 17.515151515151516
# t 41.81818181818182
# t 17.81818181818182
# t 42.121212121212125
# t 18.121212121212125
# t 42.42424242424242
# t 18.424242424242422
# t 42.72727272727273
# t 18.727272727272727
# t 43.03030303030303
# t 19.03030303030303
# t 43.333333333333336
# t 19.333333333333336
# t 43.63636363636364
# t 19.63636363636364
# t 43.93939393939394
# t 19.939393939393938
# t 44.24242424242424
# t 20.242424242424242
# t 44.54545454545455
# t 20.545454545454547
# t 44.848484848484844
# t 20.848484848484844
# t 45.151515151515156
# t 21.151515151515156
# t 45.45454545454545
# t 21.454545454545453
# t 45.75757575757576
# t 21.757575757575758
# t 46.06060606060606
# t 22.060606060606062
# t 46.36363636363636
# t 22.36363636363636
# t 46.66666666666667
# t 22.66666666666667
# t 46.96969696969697
# t 22.96969696969697
# t 47.27272727272727
# t 23.272727272727273
# t 47.57575757575758
# t 23.575757575757578
# t 47.878787878787875
# t 23.878787878787875
# t 48.18181818181819
# t 24.181818181818187
# t 48.484848484848484
# t 24.484848484848484
# t 48.78787878787879
# t 24.78787878787879
# t 49.09090909090909
# t 25.090909090909093
# t 49.39393939393939
# t 25.39393939393939
# t 49.6969696969697
# t 25.696969696969703
# t 50.0
# t 26.0
